# %% [markdown]
# # Matplotlib architecture:

# %% [raw]
# @ Scripting Layer
#         matplotlib.pyplot
# @ Artist layer
#         Artist knows how to use the Renderer to draw on the canvas.
#         Title ,lines, tick labels, and images all correspond to individual Artist instances.
#         Two types:
#             1. Primitive :Line2D, Rectangle, Circle , Text.
#             2. Composite : Axis, Tick , Axes, and Figure
# @ Backened Layer
#         Figure Canvas: matplotlib.backend_bases.FigureCanvas
#         Renderer: matplotlib.backened_bases.Renderer
#         Events: matplotlib.backened_bases.Event

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
fig= Figure()
canvas = FigureCanvas(fig)

import numpy as np
x=np.random.randn(10000)  #create 10000 random numbers using numpy 
ax=fig.add_subplot(111)  #create an axes artist
ax.hist(x,100)   #generate a histogram of 10000 numbers

#add a title to the figure
ax.set_title('Normal distribution with $\mu=0 , \sigma=1$')
fig.savefig('matplotlib_histogram.png')

# %% [raw]
# Now generating a histogram by using Matplotlib instead of Artist layer that was used above

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(x,100)
plt.title(r'Normal distribution with $\mu=0 ,\sigma=1$')
plt.savefig('matplotlib_histogram_2.png')
plt.show()

# %% [markdown]
# # Basic Plotting

# %% [markdown]
# # 1. Plot Function

# %%
# %matplotlib notebook

# %%
plt.plot(5,5,'o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.plot(4,4,'o')
plt.show()

# %%
plt.title('Plot')
# Out:
# Text(0.5, 1.0, 'Plot')
