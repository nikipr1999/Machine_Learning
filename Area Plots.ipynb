# %% [raw]
# Area plots are also known as area graph or area charts
# Used to represent cumulated totals using numbers or %ages over time
# Is based on the line plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_excel('Canada.xlsx',skiprows=range(20))

# %%
df.head()
# Out:
#          Type    Coverage          AreaName           RegName  1980  1981  \
# 0  Immigrants    Citizens  Northern America  Northern America    ..    ..
# 1  Immigrants  Foreigners            Africa    Eastern Africa  1471  1641
# 2  Immigrants  Foreigners            Africa     Middle Africa    33    27
# 3  Immigrants  Foreigners            Africa   Northern Africa  1100  1268
# 4  Immigrants  Foreigners            Africa   Southern Africa  1041  1126
#
#    1982  1983  1984  1985  ...   2004   2005   2006   2007   2008   2009  \
# 0    ..    ..    ..    ..  ...     ..     ..     ..     ..     ..     ..
# 1  1426  1094  1187  1134  ...   7726   7083   6750   6669   6705   6922
# 2    44    32    42    30  ...   2452   2802   2834   2951   3034   3255
# 3  1348   936   842   840  ...  12478  11323  12705  11750  13456  16320
# 4   791   387   297   327  ...   1203   1012   1148   1230   1184   1235
#
#     2010   2011   2012  2013
# 0     ..      1      1   NaN
# ...

# %%
df.drop(['Type','Coverage'],axis=1,inplace=True)

# %%
df.rename(columns={'AreaName':'Continent','RegName':'Region'},inplace=True)

# %%
df['total']=df.sum(axis=1)

# %%
df
# Out:
#                                 Continent                     Region   1980  \
# 0                        Northern America           Northern America     ..
# 1                                  Africa             Eastern Africa   1471
# 2                                  Africa              Middle Africa     33
# 3                                  Africa            Northern Africa   1100
# 4                                  Africa            Southern Africa   1041
# 5                                  Africa             Western Africa    306
# 6                            Africa Total                        NaN   3951
# 7                                    Asia               Central Asia     ..
# 8                                    Asia               Eastern Asia   6836
# 9                                    Asia         South-Eastern Asia   8693
# 10                                   Asia              Southern Asia  11315
# ...

# %%
df.isnull().sum()
# Out:
# Continent     0
# Region        5
# 1980          0
# 1981          0
# 1982          0
# 1983          0
# 1984          0
# 1985          0
# 1986          0
# 1987          0
# 1988          0
# 1989          0
# 1990          0
# 1991          0
# 1992          0
# 1993          0
# 1994          0
# 1995          0
# 1996          0
# 1997          0
# 1998          0
# 1999          0
# 2000          0
# 2001          0
# 2002          0
# 2003          0
# 2004          0
# 2005          0
# 2006          0
# 2007          0
# 2008          0
# 2009          0
# 2010          0
# 2011          0
# 2012          0
# 2013         29
# total         0
# dtype: int64

# %%
df.set_index('Region',inplace=True)
